# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]

# %%
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
year_counts = {}
years = []
for row in data:
    years.append(row[1])
    if row[1] in year_counts:
        year_counts[row[1]] += 1
    else:
        year_counts[row[1]] = 1
print(year_counts)
# Out:
# {'2014': 33599, '2012': 33563, '2013': 33636}

# %%
import datetime
dates = []
for row in data:
    lst = [datetime.datetime(year=int(row[1]), month=int(row[2]), day=1)]
    dates.append(lst) 
print(dates[:5])
# Out:
# [[datetime.datetime(2012, 1, 1, 0, 0)], [datetime.datetime(2012, 1, 1, 0, 0)], [datetime.datetime(2012, 1, 1, 0, 0)], [datetime.datetime(2012, 2, 1, 0, 0)], [datetime.datetime(2012, 2, 1, 0, 0)]]

# %%
date_counts = {}
for date in dates:
    if date in date_counts:
        date_counts[date] += 1
    else:
        date_counts[date] = 1

date_counts
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-12-4b4c002fd2d2> in <module>()
#       1 date_counts = {}
#       2 for date in dates:
# ----> 3     if date in date_counts:
#       4         date_counts[date] += 1
#       5     else:
#
# TypeError: unhashable type: 'list'

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
years = [row[1] for row in data]

year_counts = {}
for year in years:
    if year not in year_counts:
        year_counts[year] = 0
    year_counts[year] += 1

year_counts
# Out:
# {'2012': 33563, '2013': 33636, '2014': 33599}

# %%
import datetime

dates = [datetime.datetime(year=int(row[1]), month=int(row[2]), day=1) for row in data]
dates[:5]
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0)]

# %%
date_counts = {}

for date in dates:
    if date in date_counts:
        date_counts[date] += 1
    else:
        date_counts[date] = 1

date_counts
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 2758,
#  datetime.datetime(2012, 2, 1, 0, 0): 2357,
#  datetime.datetime(2012, 3, 1, 0, 0): 2743,
#  datetime.datetime(2012, 4, 1, 0, 0): 2795,
#  datetime.datetime(2012, 5, 1, 0, 0): 2999,
#  datetime.datetime(2012, 6, 1, 0, 0): 2826,
#  datetime.datetime(2012, 7, 1, 0, 0): 3026,
#  datetime.datetime(2012, 8, 1, 0, 0): 2954,
#  datetime.datetime(2012, 9, 1, 0, 0): 2852,
#  datetime.datetime(2012, 10, 1, 0, 0): 2733,
#  datetime.datetime(2012, 11, 1, 0, 0): 2729,
#  datetime.datetime(2012, 12, 1, 0, 0): 2791,
#  datetime.datetime(2013, 1, 1, 0, 0): 2864,
#  datetime.datetime(2013, 2, 1, 0, 0): 2375,
#  datetime.datetime(2013, 3, 1, 0, 0): 2862,
#  datetime.datetime(2013, 4, 1, 0, 0): 2798,
#  datetime.datetime(2013, 5, 1, 0, 0): 2806,
#  datetime.datetime(2013, 6, 1, 0, 0): 2920,
#  datetime.datetime(2013, 7, 1, 0, 0): 3079,
#  datetime.datetime(2013, 8, 1, 0, 0): 2859,
#  datetime.datetime(2013, 9, 1, 0, 0): 2742,
# ...

# %%
import csv
f = open("guns.csv")
data = list(csv.reader(f))
print(data[:5])
headers = []
headers.append(data[0])
data = data[1:]
print(headers)
print(data[:5])
# Out:
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education'], ['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4']]
# [['', 'year', 'month', 'intent', 'police', 'sex', 'age', 'race', 'hispanic', 'place', 'education']]
# [['1', '2012', '01', 'Suicide', '0', 'M', '34', 'Asian/Pacific Islander', '100', 'Home', '4'], ['2', '2012', '01', 'Suicide', '0', 'F', '21', 'White', '100', 'Street', '3'], ['3', '2012', '01', 'Suicide', '0', 'M', '60', 'White', '100', 'Other specified', '4'], ['4', '2012', '02', 'Suicide', '0', 'M', '64', 'White', '100', 'Home', '4'], ['5', '2012', '02', 'Suicide', '0', 'M', '31', 'White', '100', 'Other specified', '2']]

# %%
year_counts = {}
years = []
for row in data:
    years.append(row[1])
    if row[1] in year_counts:
        year_counts[row[1]] += 1
    else:
        year_counts[row[1]] = 1
print(year_counts)
total_crimes = sum(year_counts.values())
print(total_crimes)
# Out:
# {'2014': 33599, '2012': 33563, '2013': 33636}
# 100798

# %%
import datetime

dates = [datetime.datetime(year=int(row[1]), month=int(row[2]), day=1) for row in data] 

dates[:5]
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 1, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0),
#  datetime.datetime(2012, 2, 1, 0, 0)]

# %%
date_counts = {}
for date in dates:
    if date in date_counts:
        date_counts[date] += 1
    else:
        date_counts[date] = 1

date_counts
# Out:
# {datetime.datetime(2012, 1, 1, 0, 0): 2758,
#  datetime.datetime(2012, 2, 1, 0, 0): 2357,
#  datetime.datetime(2012, 3, 1, 0, 0): 2743,
#  datetime.datetime(2012, 4, 1, 0, 0): 2795,
#  datetime.datetime(2012, 5, 1, 0, 0): 2999,
#  datetime.datetime(2012, 6, 1, 0, 0): 2826,
#  datetime.datetime(2012, 7, 1, 0, 0): 3026,
#  datetime.datetime(2012, 8, 1, 0, 0): 2954,
#  datetime.datetime(2012, 9, 1, 0, 0): 2852,
#  datetime.datetime(2012, 10, 1, 0, 0): 2733,
#  datetime.datetime(2012, 11, 1, 0, 0): 2729,
#  datetime.datetime(2012, 12, 1, 0, 0): 2791,
#  datetime.datetime(2013, 1, 1, 0, 0): 2864,
#  datetime.datetime(2013, 2, 1, 0, 0): 2375,
#  datetime.datetime(2013, 3, 1, 0, 0): 2862,
#  datetime.datetime(2013, 4, 1, 0, 0): 2798,
#  datetime.datetime(2013, 5, 1, 0, 0): 2806,
#  datetime.datetime(2013, 6, 1, 0, 0): 2920,
#  datetime.datetime(2013, 7, 1, 0, 0): 3079,
#  datetime.datetime(2013, 8, 1, 0, 0): 2859,
#  datetime.datetime(2013, 9, 1, 0, 0): 2742,
# ...

# %% [markdown]
# sex_counts = {}
# race_counts = {}
# for row in data:
#     if row[5] in sex_counts:
#         sex_counts[row[5]] += 1
#     else:
#         sex_counts[row[5]] = 1
# print(sex_counts)
# for row in data:
#     if row[7] in race_counts:
#         race_counts[row[7]] += 1
#     else:
#         race_counts[row[7]] = 1
# print(race_counts)

# %% [markdown]
# Gun deaths in the US seem to disproportionately affect men vs women. They also seem to disproportionately affect minorities, although having some data on the percentage of each race in the overall US population would help.

# %%
sex_counts = []
race_counts = []
sex_crime = {}
race_crime = {}
for row in data:
    sex_counts.append(row[5])
    race_counts.append(row[7])
    if row[5] in sex_crime:
        sex_crime[row[5]] += 1
    else:
        sex_crime[row[5]] = 1
    if row[7] in race_crime:
        race_crime[row[7]] += 1
    else:
        race_crime[row[7]] = 1
print(sex_crime)
print(race_crime)
# Out:
# {'M': 86349, 'F': 14449}
# {'Asian/Pacific Islander': 1326, 'Black': 23296, 'White': 66237, 'Hispanic': 9022, 'Native American/Native Alaskan': 917}

# %% [markdown]
# Male Gun deaths in the US account for almost 86% of all deaths.  It is evident that the great mayority of deaths crimes are within "Whites" that almost triples the second group in the list "blacks".  "Whites" deaths account for almost 60% of all crime deaths by race.

# %%
f = open("census.csv")
census = list(csv.reader(f))
census
# Out:
# [['Id',
#   'Year',
#   'Id',
#   'Sex',
#   'Id',
#   'Hispanic Origin',
#   'Id',
#   'Id2',
#   'Geography',
#   'Total',
#   'Race Alone - White',
#   'Race Alone - Hispanic',
#   'Race Alone - Black or African American',
#   'Race Alone - American Indian and Alaska Native',
#   'Race Alone - Asian',
#   'Race Alone - Native Hawaiian and Other Pacific Islander',
#   'Two or More Races'],
#  ['cen42010',
#   'April 1, 2010 Census',
#   'totsex',
#   'Both Sexes',
#   'tothisp',
#   'Total',
#   '0100000US',
#   '',
#   'United States',
#   '308745538',
#   '197318956',
#   '44618105',
#   '40250635',
#   '3739506',
#   '15159516',
#   '674625',
#   '6984195']]

# %%
mapping = {}
"census_noheader = census [1:]"
"print(census_noheader)"
mapping['Asian/Pacific Islander'] = 15159516 + 674625 
"census_noheader[14] + census_noheader[15]"
mapping['Black'] = 40250635 
"census_noheader[13]"
mapping["Native American/Native Alaskan"] = 3739506
"census_noheader[14]"
mapping["Hispanic"] = 44618105
"census_noheader[12]"
mapping["White"] = 197318956
"census_noheader[11]"
race_per_hundredk = {}
for race, count in race_crime.items():
    race_per_hundredk[race] = race_crime[race] / mapping[race] * 100000 
print(race_per_hundredk)
# Out:
# {'Asian/Pacific Islander': 8.374309664161762, 'Black': 57.8773477735196, 'White': 33.56849303419181, 'Hispanic': 20.220491210910907, 'Native American/Native Alaskan': 24.521955573811088}

# %%
intents = [row[3] for row in data]
races = [row[7] for row in data]

homicide_race_counts = {}
for i, race in enumerate(races):
    if race not in homicide_race_counts:
        homicide_race_counts[race] = 0
    if intents[i] == "Homicide":
        homicide_race_counts[race] += 1

print(homicide_race_counts)
ttl_homicide = sum(homicide_race_counts.values())
print(ttl_homicide)
# Out:
# ['Asian/Pacific Islander', 'White', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Black', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'Native American/Native Alaskan', 'White', 'Black', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'White', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'Native American/Native Alaskan', 'Native American/Native Alaskan', 'White', 'White', 'White', 'Native American/Native Alaskan', 'Asian/Pacific Islander', 'White', 'White', 'Native American/Native Alaskan', 'Native American/Native Ala
# ...

# %%
racehomicide_per_hundredk = {}
for race, value in homicide_race_counts.items():
    racehomicide_per_hundredk[race] = value / mapping[race] * 100000
print(racehomicide_per_hundredk)
# Out:
# {'Asian/Pacific Islander': 3.530346230970155, 'Black': 48.471284987180944, 'White': 4.6356417981453335, 'Hispanic': 12.627161104219914, 'Native American/Native Alaskan': 8.717729026240365}

# %% [markdown]
# When filtering the data by homicides is interesting to notice that the "Black" group rate is much greater than any of the other races.  "Hispanic" group falls second however with a rate 4 times smaller than the BLack group.  Homicide intent in the "White" group represents just around 12 percent of all crimes within the group in comparison to almost 90 percent in the Black group.

# %%
crime_month = {}
for row in data:
    if row[2] in crime_month:
        crime_month[row[2]] += 1
    else:
        crime_month[row[2]] = 1
print(crime_month)
# Out:
# {'04': 8455, '02': 7093, '12': 8413, '01': 8273, '10': 8406, '06': 8677, '09': 8508, '08': 8783, '03': 8289, '05': 8669, '07': 8989, '11': 8243}

# %%
homicide_month = {}
month = [row[2] for row in data]
intents = [row[3] for row in data]
for i, month in enumerate(month):
    if month not in homicide_month:
        homicide_month[month] = 0
    if intents[i] == "Homicide":
        homicide_month[month] += 1
print(homicide_month) 
max_homicide_month = max(homicide_month.values())
max_mnth = [m for m, z in homicide_month.items() if z == max_homicide_month]
print(max_mnth, max_homicide_month)
# Out:
# {'04': 2845, '02': 2178, '12': 3191, '01': 2829, '10': 2968, '06': 3130, '09': 2966, '08': 3125, '03': 2780, '05': 2976, '07': 3269, '11': 2919}
# ['07'] 3269

# %%
dates = [datetime.datetime(year = int(row[1]), month = int(row[2]),day = 1) for row in data if row[3] == "Homicide"]
print(dates[:5])
count_dhomicide = {}
for r in dates:
    if r in count_dhomicide:
        count_dhomicide[r] += 1
    else:
        count_dhomicide[r] = 1
count_dhomicide
# Out:
# [datetime.datetime(2012, 3, 1, 0, 0), datetime.datetime(2012, 3, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0)]
# {datetime.datetime(2012, 1, 1, 0, 0): 972,
#  datetime.datetime(2012, 2, 1, 0, 0): 749,
#  datetime.datetime(2012, 3, 1, 0, 0): 966,
#  datetime.datetime(2012, 4, 1, 0, 0): 999,
#  datetime.datetime(2012, 5, 1, 0, 0): 1003,
#  datetime.datetime(2012, 6, 1, 0, 0): 1044,
#  datetime.datetime(2012, 7, 1, 0, 0): 1160,
#  datetime.datetime(2012, 8, 1, 0, 0): 1090,
#  datetime.datetime(2012, 9, 1, 0, 0): 1070,
#  datetime.datetime(2012, 10, 1, 0, 0): 979,
#  datetime.datetime(2012, 11, 1, 0, 0): 978,
#  datetime.datetime(2012, 12, 1, 0, 0): 1083,
#  datetime.datetime(2013, 1, 1, 0, 0): 986,
#  datetime.datetime(2013, 2, 1, 0, 0): 721,
#  datetime.datetime(2013, 3, 1, 0, 0): 923,
#  datetime.datetime(2013, 4, 1, 0, 0): 916,
#  datetime.datetime(2013, 5, 1, 0, 0): 955,
# ...

# %%
percentage = {}

for i,v in count_dhomicide.items():
    percentage[i] = int((v / date_counts[i]) * 100)
print(percentage)
# Out:
# {datetime.datetime(2012, 3, 1, 0, 0): 35, datetime.datetime(2013, 8, 1, 0, 0): 34, datetime.datetime(2014, 11, 1, 0, 0): 34, datetime.datetime(2012, 7, 1, 0, 0): 38, datetime.datetime(2014, 8, 1, 0, 0): 34, datetime.datetime(2013, 9, 1, 0, 0): 34, datetime.datetime(2014, 4, 1, 0, 0): 32, datetime.datetime(2012, 12, 1, 0, 0): 38, datetime.datetime(2013, 6, 1, 0, 0): 36, datetime.datetime(2013, 11, 1, 0, 0): 35, datetime.datetime(2012, 5, 1, 0, 0): 33, datetime.datetime(2014, 12, 1, 0, 0): 37, datetime.datetime(2013, 3, 1, 0, 0): 32, datetime.datetime(2013, 10, 1, 0, 0): 35, datetime.datetime(2012, 2, 1, 0, 0): 31, datetime.datetime(2014, 10, 1, 0, 0): 34, datetime.datetime(2013, 2, 1, 0, 0): 30, datetime.datetime(2014, 1, 1, 0, 0): 32, datetime.datetime(2014, 7, 1, 0, 0): 33, datetime.datetime(2014, 6, 1, 0, 0): 34, datetime.datetime(2012, 6, 1, 0, 0): 36, datetime.datetime(2014, 2, 1, 0, 0): 29, datetime.datetime(2012, 10, 1, 0, 0): 35, datetime.datetime(2013, 12, 1, 0, 0): 37, datet
# ...

# %%
dates = [datetime.datetime(year = int(row[1]), month = int(row[2]),day = 1) for row in data]
print(dates[:5])
count_dates1 = {}
for r in dates:
    if r in count_dates1:
        count_dates1[r] += 1
    else:
        count_dates1[r] = 1
# Out:
# [datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 1, 1, 0, 0), datetime.datetime(2012, 2, 1, 0, 0), datetime.datetime(2012, 2, 1, 0, 0)]

# %%
dates = [datetime.datetime(year = int(row[1]), month = int(row[2]),day = 1) for row in data if row[3] == "Homicide"]
print(dates[:5])
count_dhomicide = {}
for r in dates:
    if r in count_dhomicide:
        count_dhomicide[r] += 1
    else:
        count_dhomicide[r] = 1
# Out:
# [datetime.datetime(2012, 3, 1, 0, 0), datetime.datetime(2012, 3, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0), datetime.datetime(2012, 4, 1, 0, 0)]

# %%
education_crime = {}

for row in data:
    if row[10] in education_crime:
        education_crime[row[10]] += 1
    else:
        education_crime[row[10]] = 1
print(education_crime)
# Out:
# {'1': 21823, '3': 21680, '2': 42927, '5': 1369, '4': 12946, 'NA': 53}

# %%
education_homicide = {}
intent = {}
education = [row[10] for row in data]
intent = [row[3] for row in data]
for k,v in enumerate(education):
    if v not in education_homicide:
        education_homicide[v] = 0
    if intent[k] == "Homicide":
        education_homicide[v] += 1
print(education_homicide)
# Out:
# {'1': 11839, '3': 5640, '2': 15649, '5': 455, '4': 1559, 'NA': 34}

# %% [markdown]
# Homicide intents clearly ocurred more often within groups of people with lower degree of education. People graduated from High school or less account for more than 75 percent of all homicide intents within the sample data.

# %%
police_involved = [row[4] for row in data]
intent = [row[3] for row in data]
policeinv_count = 0
for i,v in enumerate(police_involved):
    if v == "1" and intent[i] == "Homicide":
        policeinv_count += 1
print(policeinv_count)  
percinvolved = policeinv_count / ttl_homicide * 100
print(percinvolved)
# Out:
# 1402
# 3.985672049124403

# %% [markdown]
# A police officer was involved in only 4% of all homicides.

# %%
for i,v in enumerate(police_involved):
    if v == "1" and intent[i] == "Suicide":
        policeinv_count += 1
print(policeinv_count)  
percinvolved = policeinv_count / ttl_homicide * 100
print(percinvolved)
count = 0
for row in data:
    if row[4] == "1" and row[3] == "Homicide":
        count += 1
    
print(count)
# Out:
# 1402
# 3.985672049124403
# 1402

# %%
for row in data:
    if row[6] == "NA":
        row[6] = 0
ages = [int(row[6]) for row in data]
intent = [row[3] for row in data]
ages_crime= {}

for i,v in enumerate(ages):
    if v not in ages_crime:
        ages_crime[v] = 0
    if intent[i] == "Homicide":
        ages_crime[v] += 1
        
print(ages_crime)
# Out:
# {0: 31, 1: 34, 2: 29, 3: 36, 4: 32, 5: 34, 6: 42, 7: 38, 8: 23, 9: 36, 10: 37, 11: 39, 12: 50, 13: 85, 14: 125, 15: 261, 16: 474, 17: 710, 18: 1138, 19: 1364, 20: 1467, 21: 1570, 22: 1628, 23: 1459, 24: 1442, 25: 1300, 26: 1245, 27: 1136, 28: 1119, 29: 1055, 30: 993, 31: 928, 32: 964, 33: 884, 34: 867, 35: 782, 36: 718, 37: 646, 38: 625, 39: 552, 40: 555, 41: 540, 42: 537, 43: 493, 44: 435, 45: 399, 46: 401, 47: 438, 48: 386, 49: 414, 50: 387, 51: 375, 52: 336, 53: 295, 54: 261, 55: 232, 56: 250, 57: 214, 58: 204, 59: 204, 60: 145, 61: 155, 62: 155, 63: 112, 64: 130, 65: 101, 66: 106, 67: 89, 68: 95, 69: 60, 70: 54, 71: 56, 72: 51, 73: 58, 74: 43, 75: 35, 76: 40, 77: 25, 78: 46, 79: 29, 80: 37, 81: 26, 82: 20, 83: 28, 84: 30, 85: 19, 86: 11, 87: 12, 88: 11, 89: 12, 90: 10, 91: 3, 92: 3, 93: 3, 94: 2, 95: 3, 96: 3, 97: 2, 98: 0, 99: 1, 100: 0, 101: 0, 102: 0, 107: 1}

# %%
range_crime = {}
zero = 0
under_ten = 0
ten_to_20 = 0
twenty1_to_30 = 0
thirty1_to_40 = 0
forty1_to_50 = 0
fifty1_to_60 = 0
sixty1_plus = 0
for row in data:
    if int(row[6]) > 0 and int(row[6]) < 10:
        under_ten += 1
    if int(row[6]) > 9 and int(row[6]) < 21:
        ten_to_20 += 1   
    if int(row[6]) > 20 and int(row[6]) < 31:
        twenty1_to_30 += 1 
    if int(row[6]) > 30 and int(row[6]) < 41:
        thirty1_to_40 += 1
    if int(row[6]) > 40 and int(row[6]) < 51:
        forty1_to_50 += 1
    if int(row[6]) > 50 and int(row[6]) < 61:
        fifty1_to_60 += 1
    if int(row[6]) > 60:
        sixty1_plus += 1    
range_crime["under_ten"] = under_ten
range_crime["ten_to_20"] = ten_to_20
range_crime["twenty1_to_30"] = twenty1_to_30
range_crime["thirty1_to_40"] = thirty1_to_40
range_crime["forty1_to_50"] = forty1_to_50
range_crime["fifty1_to_60"] = fifty1_to_60
range_crime["sixty1_plus"] = sixty1_plus
ttl_crime = sum(range_crime.values())
print(ttl_crime)
print(range_crime)
max_rangecount = max(range_crime.values())
max_rangecrime = [m for m, z in range_crime.items() if z == max_rangecount]
print(max_rangecount, max_rangecrime)
# Out:
# 100747
# {'twenty1_to_30': 22466, 'forty1_to_50': 15258, 'fifty1_to_60': 15856, 'thirty1_to_40': 15993, 'under_ten': 423, 'sixty1_plus': 21280, 'ten_to_20': 9471}
# 22466 ['twenty1_to_30']

# %%
range_homicide = {}
zero = 0
under_ten = 0
ten_to_20 = 0
twenty1_to_30 = 0
thirty1_to_40 = 0
forty1_to_50 = 0
fifty1_to_60 = 0
sixty1_plus = 0
for row in data:
    if int(row[6]) > 0 and int(row[6]) < 10 and row[3] == "Homicide":
        under_ten += 1
    if int(row[6]) > 9 and int(row[6]) < 21 and row[3] == "Homicide":
        ten_to_20 += 1   
    if int(row[6]) > 20 and int(row[6]) < 31 and row[3] == "Homicide":
        twenty1_to_30 += 1 
    if int(row[6]) > 30 and int(row[6]) < 41 and row[3] == "Homicide":
        thirty1_to_40 += 1
    if int(row[6]) > 40 and int(row[6]) < 51 and row[3] == "Homicide":
        forty1_to_50 += 1
    if int(row[6]) > 50 and int(row[6]) < 61 and row[3] == "Homicide":
        fifty1_to_60 += 1
    if int(row[6]) > 60 and row[3] == "Homicide":
        sixty1_plus += 1    
range_homicide["under_ten"] = under_ten
range_homicide["ten_to_20"] = ten_to_20
range_homicide["twenty1_to_30"] = twenty1_to_30
range_homicide["thirty1_to_40"] = thirty1_to_40
range_homicide["forty1_to_50"] = forty1_to_50
range_homicide["fifty1_to_60"] = fifty1_to_60
range_homicide["sixty1_plus"] = sixty1_plus


print(range_homicide)
# Out:
# {'twenty1_to_30': 12947, 'forty1_to_50': 4430, 'fifty1_to_60': 2516, 'thirty1_to_40': 7521, 'under_ten': 304, 'sixty1_plus': 1677, 'ten_to_20': 5750}

# %%
range_suicide = {}
zero = 0
under_ten = 0
ten_to_20 = 0
twenty1_to_30 = 0
thirty1_to_40 = 0
forty1_to_50 = 0
fifty1_to_60 = 0
sixty1_plus = 0
for row in data:
    if int(row[6]) > 0 and int(row[6]) < 10 and row[3] == "Suicide":
        under_ten += 1
    
    if int(row[6]) > 9 and int(row[6]) < 21 and row[3] == "Suicide":
        ten_to_20 += 1   
    if int(row[6]) > 20 and int(row[6]) < 31 and row[3] == "Suicide":
        twenty1_to_30 += 1 
    if int(row[6]) > 30 and int(row[6]) < 41 and row[3] == "Suicide":
        thirty1_to_40 += 1
    if int(row[6]) > 40 and int(row[6]) < 51 and row[3] == "Suicide":
        forty1_to_50 += 1
    if int(row[6]) > 50 and int(row[6]) < 61 and row[3] == "Suicide":
        fifty1_to_60 += 1
    if int(row[6]) > 60 and row[3] == "Suicide":
        sixty1_plus += 1    
under_ten = under_ten - zero
range_suicide["under_ten"] = under_ten
range_suicide["ten_to_20"] = ten_to_20
range_suicide["twenty1_to_30"] = twenty1_to_30
range_suicide["thirty1_to_40"] = thirty1_to_40
range_suicide["forty1_to_50"] = forty1_to_50
range_suicide["fifty1_to_60"] = fifty1_to_60
range_suicide["sixty1_plus"] = sixty1_plus
print(range_suicide)        

intent_over60 = {}
for row in data:
    if int(row[6]) > 60:
        if row[3] in intent_over60:
            intent_over60[row[3]] += 1
        else:
            intent_over60[row[3]] = 1
        
print(intent_over60)
# Out:
# {'twenty1_to_30': 8976, 'forty1_to_50': 10516, 'fifty1_to_60': 12988, 'thirty1_to_40': 8142, 'under_ten': 2, 'sixty1_plus': 19192, 'ten_to_20': 3352}
# {'Accidental': 283, 'Undetermined': 128, 'Homicide': 1677, 'Suicide': 19192}

# %% [markdown]
# Analising the data by age range we can conclude that the group age mostly affected by crime "intents" is the population on their twenties. Not far are the over sixties.  However the homicide intent accounts for more than 50 percent on the "twenties" age group and the suicide intant being over
